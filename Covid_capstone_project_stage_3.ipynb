# %% [markdown]
# # **Implementing the Model (Stage 3)**

# %% [markdown]
# **Method**
#
#
#
# *   Download the trained model, and copy the tensorflow code
# *   Upload the model to the google drive
# *   change the file path in the code to your model and label
# *   Test the model by uploading image from different categories
#
#
# **Model Accuracy Percentage**
#
# Covid: 99%
#
# Normal: 93%
#
# Virus: 92%

# %% [markdown]
# # **First Test**

# %% [markdown]
# **Test Plan:**
# Testing the model for the virus scenario. In this test, I will use an image from the virus class in the dataset. In that class, all the x-ray images belong to individuals with viruses, so the model should predict viruses if it works correctly.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/keras_model.h5", compile=False)

# Load the labels
class_names = open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/virus/person108_virus_200.jpeg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 724ms/step
# Class: virus
# Confidence Score: 0.99874973

# %%
from warnings import filterwarnings
import tensorflow as tf
from tensorflow import io
from tensorflow import image
from matplotlib import pyplot as plt

filterwarnings("ignore")
tf_img = io.read_file("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/virus/person108_virus_200.jpeg")
tf_img = image.decode_png(tf_img, channels=3)
print(tf_img.dtype)
plt.imshow(tf_img)
# Out:
# <dtype: 'uint8'>

# %% [markdown]
# # **Observations**(First Test)
# After running the code, the model was able to successfully predict from the image that this image belongs to a person who has a virus. This prediction is accurate because the image was taken from the file that belonged to people with the virus. The model predicted this case with a confidence score of 99%, which is amazing, and also below that the image has been generated to show the image used.

# %% [markdown]
# # **Second Test**

# %% [markdown]
# **Test Plan:** Testing the model for the Normal scenario. In this test, I will use an image from the normal class in the dataset. In that class, all the x-ray images belong to individuals with normal conditions that do not have any viruses or covid, so the model should predict normal if it works correctly.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/keras_model.h5", compile=False)

# Load the labels
class_names = open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/normal/IM-0010-0001.jpeg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: normal
# Confidence Score: 0.9892229

# %%
from warnings import filterwarnings
import tensorflow as tf
from tensorflow import io
from tensorflow import image
from matplotlib import pyplot as plt

filterwarnings("ignore")
tf_img = io.read_file("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/normal/IM-0010-0001.jpeg")
tf_img = image.decode_png(tf_img, channels=3)
print(tf_img.dtype)
plt.imshow(tf_img)
# Out:
# <dtype: 'uint8'>

# %% [markdown]
# # **Observations**(Second Test)

# %% [markdown]
# After running the code, the model was able to successfully predict from the image that this image belongs to a person who has a no conditions and is normal. This prediction is accurate because the image was taken from the file that belonged to people with the no conditions (normal). The model predicted this case with a confidence score of 98%, which is amazing, and also below that the image has been generated to show the image used.

# %% [markdown]
# # **Third Test**

# %% [markdown]
# **Test Plan:**  In this test, I have used an image from the COVID class to check if the model is able to predict from the x-ray image that the image belongs to the COVID class. If the model works correctly, it should predict COVID.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/keras_model.h5", compile=False)

# Load the labels
class_names = open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/covid/1-s2.0-S1684118220300608-main.pdf-001.jpg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: covid
# Confidence Score: 0.99995947

# %%
from warnings import filterwarnings
import tensorflow as tf
from tensorflow import io
from tensorflow import image
from matplotlib import pyplot as plt

filterwarnings("ignore")
tf_img = io.read_file("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/covid/1-s2.0-S1684118220300608-main.pdf-001.jpg")
tf_img = image.decode_png(tf_img, channels=3)
print(tf_img.dtype)
plt.imshow(tf_img)
# Out:
# <dtype: 'uint8'>

# %% [markdown]
# # **Observations**(Third Test)
#
# The model was able to successfully predict from the image that this image belongs to a person who has covid. This prediction is accurate because the image was taken from the file that belonged to people with covid. The model predicted this case with a confidence score of 99%,and also below that the image has been generated to show the image used.

# %% [markdown]
# # **Fourth Test**

# %% [markdown]
# **Test Plan:** Testing the model for the Normal scenario for the second time. Same as before, in this test, I will use an image from the normal class in the dataset. In that class, all the x-ray images belong to individuals with normal conditions that do not have any viruses or covid, so the model should predict normal if it works correctly.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/keras_model.h5", compile=False)

# Load the labels
class_names = open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/normal/IM-0255-0001.jpeg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 953ms/step
# Class: normal
# Confidence Score: 0.9995515

# %%
from warnings import filterwarnings
import tensorflow as tf
from tensorflow import io
from tensorflow import image
from matplotlib import pyplot as plt

filterwarnings("ignore")
tf_img = io.read_file("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/normal/IM-0255-0001.jpeg")
tf_img = image.decode_png(tf_img, channels=3)
print(tf_img.dtype)
plt.imshow(tf_img)
# Out:
# <dtype: 'uint8'>

# %% [markdown]
# # **Observations**(Fourth Test)
#
# In the fourth test the model was able to successfully predict from the image that this image belongs to a person who has no condition and is normal. This prediction is accurate because the image was indeed taken from the file that belonged to people who are normal. The model predicted this case with a confidence score of 99%,and also below that the image has been generated to show the image used.

# %% [markdown]
# # **Fifth Test**

# %% [markdown]
# **Test Plan:** Testing the model for the virus scenario for the second time. In this test, I will use an image from the virus class in the dataset same as before. In that class, all the x-ray images belong to individuals with viruses, so the model should predict viruses if it works correctly.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/keras_model.h5", compile=False)

# Load the labels
class_names = open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/virus/person110_virus_207.jpeg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: virus
# Confidence Score: 0.99998355

# %%
from warnings import filterwarnings
import tensorflow as tf
from tensorflow import io
from tensorflow import image
from matplotlib import pyplot as plt

filterwarnings("ignore")
tf_img = io.read_file("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/virus/person110_virus_207.jpeg")
tf_img = image.decode_png(tf_img, channels=3)
print(tf_img.dtype)
plt.imshow(tf_img)
# Out:
# <dtype: 'uint8'>

# %% [markdown]
# # **Observations**(Fifth Test)
#
# In the fifth test the model was able to successfully predict from the image that this image belongs to a person who has a virus. This prediction is accurate because the image was indeed taken from the file that belonged to people with virus. The model predicted this case with a confidence score of 99%,and also below that the image has been generated to show the image used.

# %% [markdown]
# # **Sixth Test**

# %% [markdown]
# **Test Plan:** Same as before, in this test, I have used an image from the COVID class to check if the model is able to predict from the x-ray image that the image belongs to the COVID class. If the model works correctly, it should predict COVID.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/keras_model.h5", compile=False)

# Load the labels
class_names = open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/converted_keras/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3a.png").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: covid
# Confidence Score: 1.0

# %%
from warnings import filterwarnings
import tensorflow as tf
from tensorflow import io
from tensorflow import image
from matplotlib import pyplot as plt

filterwarnings("ignore")
tf_img = io.read_file("/content/drive/MyDrive/Capstone_project_u3269348_Mir_Hameedullah_Ibrahimi/COVID_IEEE_dataset/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3a.png")
tf_img = image.decode_png(tf_img, channels=3)
print(tf_img.dtype)
plt.imshow(tf_img)
# Out:
# <dtype: 'uint8'>

# %% [markdown]
# # **Observations**(Sixth Test)
#
# The model was able to successfully predict from the image that this image belongs to a person who has covid. This prediction is accurate because the image was taken from the file that belonged to people with covid. The model predicted this case with a confidence score of 100%,and also below that the image has been generated to show the image used.
